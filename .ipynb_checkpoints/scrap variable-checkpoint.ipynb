# %%
# from selenium import webdriver
# from time import sleep
# import pandas as pd
# from selenium.webdriver.firefox.options import Options

# URL = 'http://1.10.141.27:8010/dpc10/r506_week/zone.php?CMD=DRILLDOWN&MINX=194682.434294&MINY=1871408.47178&MAXX=878592.640952&MAXY=2294250.18193&p_disease=g01&pvalue=sickrate&p_year1=2554&p_week1=1&p_year2=2564&p_week2=53&area_code=10&search=%E1%CA%B4%A7%A2%E9%CD%C1%D9%C5'
# opts = Options()
# opts.headless = True
# browser = webdriver.Firefox(options=opts,executable_path = r'C:\Users\DELL\geckodriver.exe')
# browser.get(URL)
# sleep(2)

# values = browser.find_element_by_id("p_disease")
# print(values.get_attribute("text"))
# print(values.get_attribute("outerHTML"))
# Texts = values.get_attribute("text")
# browser.close()
# Out:
# None
# <select id="p_disease" name="p_disease" size="1">
# 					  						<option value="65">Acute Flaccid Paralysis</option>
# 														<option value="78">AEFI</option>
# 														<option value="61">Amoebiasis other organ</option>
# 														<option value="45">Anthrax</option>
# 														<option value="83">Brucellosis</option>
# 														<option value="63">Capillariasis</option>
# 														<option value="73">Cassava poisoning</option>
# 														<option value="17">Chickenpox</option>
# 														<option value="84">Chikungunya fever</option>
# 														<option value="01">Cholera</option>
# 														<option value="g01" selected="">D.H.F,Total(26,27,66)</option>
# 														<option value="26">&nbsp;&nbsp; &gt;&gt;D.H.F.</option>
# 												<option value="27">&nbsp;&nbsp; &gt;&gt;D.H.F.shock syndrome</option>
# 												<option value="66">&nbsp;&nbsp; &gt;&gt;Dengue fever</option>
# 												<option value="02">Diarrhoea</option>
# 														<option value="23">Diphtheria</option>
# 														<option value="57">Drug poisoning</option>
# 														<option value="g02">Dysentery (04,05,06)</option>
# 														<option value="06">&nbsp;&nbsp; &gt;&gt;Dysentery,Amoebic</option>
# 												<option value="05">&nbsp;&nbsp; &gt;&gt;Dysentery,Bacillary</option>
# 												<option value="04">&nbsp;&nbsp; &gt;&gt;Uns.dysentery</option>
# 												<option value="g03">Encephalitis,total(28,29)</option>
# 														<option value="28">&nbsp;&nbsp; &gt;&gt;Encephalitis uns.</option>
# 												<option value="29">&nbsp;&nbsp; &gt;&gt;Japanese B encephalitis</option>
# 												<option value="g04">Enteric fever(07,08,09)</option>
# 														<option value="07">&nbsp;&nbsp; &gt;&gt;Enteric fever</option>
# 												<option value="09">&nbsp;&nbsp; &gt;&gt;Paratyphoid</option>
# 												<option value="08">&nbsp;&nbsp; &gt;&gt;Typhoid</option>
# 												<option value="55">Eosinophilic Meningitis</option>
# 														<option value="76">Filariasis</option>
# 														<option value="03">Food Poisoning</option>
# 														<option value="14">H.conjunctivitis</option>
# 														<option value="71">Hand,foot and mouth disease</option>
# 														<option value="g05">Hepatitis,total (10-13,69-70)</option>
# 														<option value="11">&nbsp;&nbsp; &gt;&gt;Hepatitis A</option>
# 												<option value="12">&nbsp;&nbsp; &gt;&gt;Hepatitis B</option>
# 												<option value="13">&nbsp;&nbsp; &gt;&gt;Hepatitis C</option>
# 												<option value="69">&nbsp;&nbsp; &gt;&gt;Hepatitis D</option>
# 												<option value="70">&nbsp;&nbsp; &gt;&gt;Hepatitis E</option>
# 												<option value="10">&nbsp;&nbsp; &gt;&gt;Hepatitis uns.</option>
# 												<option value="77">Herpes zoster</option>
# 														<option value="15">Influenza</option>
# 														<option value="68">Kala azar</option>
# 														<option value="35">Leprosy</option>
# 														<option value="43">Leptospirosis</option>
# 														<option value="75">Liver fluke</option>
# 														<option value="30">Malaria</option>
# 														<option value="g06">Measles,total (21-22)</option>
# 														<option value="21">&nbsp;&nbsp; &gt;&gt;Measles</option>
# 												<option value="22">&nbsp;&nbsp; &gt;&gt;Measles c Complication</option>
# 												<option value="72">Melioidosis</option>
# 														<option value="54">Meningitis,uns.</option>
# 														<option value="19">Meningococcal Meningitis</option>
# 														<option value="52">Mumps</option>
# 														<option value="58">Mushroom poisoning</option>
# 														<option value="g07">Occupational diseases</option>
# 														<option value="51">&nbsp;&nbsp; &gt;&gt;Gas vapor poisoning</option>
# 												<option value="48">&nbsp;&nbsp; &gt;&gt;Lead poisoning</option>
# 												<option value="49">&nbsp;&nbsp; &gt;&gt;Mn,Hg,As poisoning</option>
# 												<option value="47">&nbsp;&nbsp; &gt;&gt;Pesticide poisoning</option>
# 												<option value="50">&nbsp;&nbsp; &gt;&gt;Petroleum poisoning</option>
# 												<option value="24">Pertussis</option>
# 														<option value="67">Physical Hazard</option>
# 														<option value="64">Pneumoconiosis</option>
# 														<option value="31">Pneumonia</option>
# 														<option value="20">Poliomyelitis</option>
# 														<option value="18">Pyrexia</option>
# 														<option value="42">Rabies</option>
# 														<option value="62">Reye's syndrome</option>
# 														<option value="16">Rubella</option>
# 														<option value="g08">S.T.D.,total(37-41,79-81)</option>
# 														<option value="40">&nbsp;&nbsp; &gt;&gt;Chancroid</option>
# 												<option value="38">&nbsp;&nbsp; &gt;&gt;Gonorrhoea</option>
# 												<option value="41">&nbsp;&nbsp; &gt;&gt;L.G.V.</option>
# 												<option value="39">&nbsp;&nbsp; &gt;&gt;N.S.U.</option>
# 												<option value="37">&nbsp;&nbsp; &gt;&gt;Syphilis</option>
# 												<option value="79">&nbsp;&nbsp; &gt;&gt;เริมที่อวัยวะเพศ</option>
# 												<option value="81">&nbsp;&nbsp; &gt;&gt;โรคติดต่อทางเพศสัมพันธ์อื่น ๆ</option>
# 												<option value="80">&nbsp;&nbsp; &gt;&gt;หูดอวัยวะเพศและทวารหนัก</option>
# 												<option value="74">Scarlet fever</option>
# 														<option value="44">Scrub Typhus</option>
# 														<option value="56">Snake bite</option>
# 														<option value="82">Streptococcus suis</option>
# 														<option value="60">Suicide</option>
# 														<option value="g09">Tetanus inc.Neo.(25,53)</option>
# 														<option value="25">&nbsp;&nbsp; &gt;&gt;Tetanus exc.Neo.</option>
# 												<option value="53">&nbsp;&nbsp; &gt;&gt;Tetanus neonatorum</option>
# 												<option value="46">Trichinosis</option>
# 														<option value="59">Tropical ulcer</option>
# 														<option value="g10">Tuberculosis,total(32-34)</option>
# 														<option value="32">&nbsp;&nbsp; &gt;&gt;Pulmonary T.B.</option>
# 												<option value="34">&nbsp;&nbsp; &gt;&gt;T.B. other organs</option>
# 												<option value="33">&nbsp;&nbsp; &gt;&gt;T.B.meningitis</option>
# 												<option value="36">Yaw,infectious</option>
# 													</select>

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

URL = '''http://1.10.141.27:8010/dpc10/r506_week/zone.php?CMD=DRILLDOWN&
        MINX=194682.434294&MINY=1871408.47178&MAXX=878592.640952&MAXY=2294250.18193
        &p_disease=g01&pvalue=sickrate&p_year1=2554&p_week1=1&p_year2=2564&p_week2=53
        &area_code=10&search=%E1%CA%B4%A7%A2%E9%CD%C1%D9%C5'''
response = requests.get(URL)
# response.encoding = 'utf-8-sig'
document = BeautifulSoup(response.text,'lxml')
# print(document.prettify())

Selects = document.find("select",attrs = {"id":"p_disease"})
# print(Selects.prettify())
all_values = Selects.find_all('option')
all_values
# Out:
# [<option value="65">Acute Flaccid Paralysis</option>,
#  <option value="78">AEFI</option>,
#  <option value="61">Amoebiasis other organ</option>,
#  <option value="45">Anthrax</option>,
#  <option value="83">Brucellosis</option>,
#  <option value="63">Capillariasis</option>,
#  <option value="73">Cassava poisoning</option>,
#  <option value="17">Chickenpox</option>,
#  <option value="84">Chikungunya fever</option>,
#  <option value="01">Cholera</option>,
#  <option selected="" value="g01">D.H.F,Total(26,27,66)</option>,
#  <option value="26">   &gt;&gt;D.H.F.</option>,
#  <option value="27">   &gt;&gt;D.H.F.shock syndrome</option>,
#  <option value="66">   &gt;&gt;Dengue fever</option>,
#  <option value="02">Diarrhoea</option>,
#  <option value="23">Diphtheria</option>,
#  <option value="57">Drug poisoning</option>,
#  <option value="g02">Dysentery (04,05,06)</option>,
#  <option value="06">   &gt;&gt;Dysentery,Amoebic</option>,
#  <option value="05">   &gt;&gt;Dysentery,Bacillary</option>,
#  <option value="04">   &gt;&gt;Uns.dysentery</option>,
#  <option value="g03">Encephalitis,total(28,29)</option>,
#  <option value="28">   &gt;&gt;Encephalitis uns.</option>,
#  <option value="29">   &gt;&gt;Japanese B encephalitis</option>,
#  <option value="g04">Enteric fever(07,08,09)</option>,
#  <option value="07">   &gt;&gt;Enteric fever</option>,
#  <option value="09">   &gt;&gt;Paratyphoid</option>,
#  <option value="08">   &gt;&gt;Typhoid</option>,
#  <option value="55">Eosinophilic Meningitis</option>,
#  <option value="76">Filariasis</option>,
#  <option value="03">Food Poisoning</option>,
#  <option value="14">H.conjunctivitis</option>,
#  <option value="71">Hand,foot and mouth disease</option>,
#  <option value="g05">Hepatitis,total (10-13,69-70)</option>,
#  <option value="11">   &gt;&gt;Hepatitis A</option>,
#  <option value="12">   &gt;&gt;Hepatitis B</option>,
#  <option value="13">   &gt;&gt;Hepatitis C</option>,
#  <option value="69">   &gt;&gt;Hepatitis D</option>,
#  <option value="70">   &gt;&gt;Hepatitis E</option>,
#  <option value="10">   &gt;&gt;Hepatitis uns.</option>,
#  <option value="77">Herpes zoster</option>,
#  <option value="15">Influenza</option>,
#  <option value="68">Kala azar</option>,
#  <option value="35">Leprosy</option>,
#  <option value="43">Leptospirosis</option>,
#  <option value="75">Liver fluke</option>,
#  <option value="30">Malaria</option>,
#  <option value="g06">Measles,total (21-22)</option>,
#  <option value="21">   &gt;&gt;Measles</option>,
#  <option value="22">   &gt;&gt;Measles c Complication</option>,
#  <option value="72">Melioidosis</option>,
#  <option value="54">Meningitis,uns.</option>,
#  <option value="19">Meningococcal Meningitis</option>,
#  <option value="52">Mumps</option>,
#  <option value="58">Mushroom poisoning</option>,
#  <option value="g07">Occupational diseases</option>,
#  <option value="51">   &gt;&gt;Gas vapor poisoning</option>,
#  <option value="48">   &gt;&gt;Lead poisoning</option>,
#  <option value="49">   &gt;&gt;Mn,Hg,As poisoning</option>,
#  <option value="47">   &gt;&gt;Pesticide poisoning</option>,
#  <option value="50">   &gt;&gt;Petroleum poisoning</option>,
#  <option value="24">Pertussis</option>,
#  <option value="67">Physical Hazard</option>,
#  <option value="64">Pneumoconiosis</option>,
#  <option value="31">Pneumonia</option>,
#  <option value="20">Poliomyelitis</option>,
#  <option value="18">Pyrexia</option>,
#  <option value="42">Rabies</option>,
#  <option value="62">Reye's syndrome</option>,
#  <option value="16">Rubella</option>,
#  <option value="g08">S.T.D.,total(37-41,79-81)</option>,
#  <option value="40">   &gt;&gt;Chancroid</option>,
#  <option value="38">   &gt;&gt;Gonorrhoea</option>,
#  <option value="41">   &gt;&gt;L.G.V.</option>,
#  <option value="39">   &gt;&gt;N.S.U.</option>,
#  <option value="37">   &gt;&gt;Syphilis</option>,
#  <option value="79">   &gt;&gt;àÃÔÁ·ÕèÍÇÑÂÇÐà¾È</option>,
#  <option value="81">   &gt;&gt;âÃ¤µÔ´µèÍ·Ò§à¾ÈÊÑÁ¾Ñ¹¸ìÍ×è¹ æ</option>,
#  <option value="80">   &gt;&gt;ËÙ´ÍÇÑÂÇÐà¾ÈáÅÐ·ÇÒÃË¹Ñ¡</option>,
#  <option value="74">Scarlet fever</option>,
#  <option value="44">Scrub Typhus</option>,
#  <option value="56">Snake bite</option>,
#  <option value="82">Streptococcus suis</option>,
#  <option value="60">Suicide</option>,
#  <option value="g09">Tetanus inc.Neo.(25,53)</option>,
#  <option value="25">   &gt;&gt;Tetanus exc.Neo.</option>,
#  <option value="53">   &gt;&gt;Tetanus neonatorum</option>,
#  <option value="46">Trichinosis</option>,
#  <option value="59">Tropical ulcer</option>,
#  <option value="g10">Tuberculosis,total(32-34)</option>,
#  <option value="32">   &gt;&gt;Pulmonary T.B.</option>,
#  <option value="34">   &gt;&gt;T.B. other organs</option>,
#  <option value="33">   &gt;&gt;T.B.meningitis</option>,
#  <option value="36">Yaw,infectious</option>]

# %%
values = [value['value'] for value in all_values]
values
# Out:
# ['65',
#  '78',
#  '61',
#  '45',
#  '83',
#  '63',
#  '73',
#  '17',
#  '84',
#  '01',
#  'g01',
#  '26',
#  '27',
#  '66',
#  '02',
#  '23',
#  '57',
#  'g02',
#  '06',
#  '05',
#  '04',
#  'g03',
#  '28',
#  '29',
#  'g04',
#  '07',
#  '09',
#  '08',
#  '55',
#  '76',
#  '03',
#  '14',
#  '71',
#  'g05',
#  '11',
#  '12',
#  '13',
#  '69',
#  '70',
#  '10',
#  '77',
#  '15',
#  '68',
#  '35',
#  '43',
#  '75',
#  '30',
#  'g06',
#  '21',
#  '22',
#  '72',
#  '54',
#  '19',
#  '52',
#  '58',
#  'g07',
#  '51',
#  '48',
#  '49',
#  '47',
#  '50',
#  '24',
#  '67',
#  '64',
#  '31',
#  '20',
#  '18',
#  '42',
#  '62',
#  '16',
#  'g08',
#  '40',
#  '38',
#  '41',
#  '39',
#  '37',
#  '79',
#  '81',
#  '80',
#  '74',
#  '44',
#  '56',
#  '82',
#  '60',
#  'g09',
#  '25',
#  '53',
#  '46',
#  '59',
#  'g10',
#  '32',
#  '34',
#  '33',
#  '36']

# %%
from selenium import webdriver
from time import sleep
import pandas as pd
from selenium.webdriver.firefox.options import Options

for i in values:
    URL = f'''http://1.10.141.27:8010/dpc10/r506_month/zone.php?CMD=DRILLDOWN&MINX=194682.434294&
    MINY=1871408.47178&MAXX=878592.640952&MAXY=2294250.18193&p_disease={i}&pvalue=sickrate&p_year1=2553
    &p_month1=1&p_year2=2565&p_month2=12
    &area_code=10&search=%E1%CA%B4%A7%A2%E9%CD%C1%D9%C5'''
    browser = webdriver.Firefox(executable_path = r'C:\Users\DELL\geckodriver.exe')
    browser.get(URL)
    sleep(2)
    export_file_btn = browser.find_element_by_xpath('/html/body/form/center/center/input')
    export_file_btn.click()
    browser.close()

# %%
# Column names
names = []
for v in all_values:
#     print(v.text)
    if v.text.startswith("\xa0\xa0"):
#         print(v.text[5:])
        name = v.text[5:]
    else:
#         print(v.text)
        name = v.text
    names.append(name)
print(names)
print(len(names))
# Out:
# ['Acute Flaccid Paralysis', 'AEFI', 'Amoebiasis other organ', 'Anthrax', 'Brucellosis', 'Capillariasis', 'Cassava poisoning', 'Chickenpox', 'Chikungunya fever', 'Cholera', 'D.H.F,Total(26,27,66)', 'D.H.F.', 'D.H.F.shock syndrome', 'Dengue fever', 'Diarrhoea', 'Diphtheria', 'Drug poisoning', 'Dysentery (04,05,06)', 'Dysentery,Amoebic', 'Dysentery,Bacillary', 'Uns.dysentery', 'Encephalitis,total(28,29)', 'Encephalitis uns.', 'Japanese B encephalitis', 'Enteric fever(07,08,09)', 'Enteric fever', 'Paratyphoid', 'Typhoid', 'Eosinophilic Meningitis', 'Filariasis', 'Food Poisoning', 'H.conjunctivitis', 'Hand,foot and mouth disease', 'Hepatitis,total (10-13,69-70)', 'Hepatitis A', 'Hepatitis B', 'Hepatitis C', 'Hepatitis D', 'Hepatitis E', 'Hepatitis uns.', 'Herpes zoster', 'Influenza', 'Kala azar', 'Leprosy', 'Leptospirosis', 'Liver fluke', 'Malaria', 'Measles,total (21-22)', 'Measles', 'Measles c Complication', 'Melioidosis', 'Meningitis,uns.', 'Meningococcal Meningitis', 'Mumps', 'Mushroom poisoning', 'Occupational diseases', 'Gas vapor poisoning', 'Lead poisoning', 'Mn,Hg,As poisoning', 'Pesticide poisoning', 'Petroleum poisoning', 'Pertussis', 'Physical Hazard', 'Pneumoconiosis', 'Pneumonia', 'Poliomyelitis', 'Pyrexia', 'Rabies', "Reye's syndrome", 'Rubella', 'S.T.D.,total(37-41,79-81)', 'Chancroid', 'Gonorrhoea', 'L.G.V.', 'N.S.U.', 'Syphilis', 'àÃÔÁ·ÕèÍÇÑÂÇÐà¾È', 'âÃ¤µÔ´µèÍ·Ò§à¾ÈÊÑÁ¾Ñ¹¸ìÍ×è¹ æ', 'ËÙ´ÍÇÑÂÇÐà¾ÈáÅÐ·ÇÒÃË¹Ñ¡', 'Scarlet fever', 'Scrub Typhus', 'Snake bite', 'Streptococcus suis', 'Suicide', 'Tetanus inc.Neo.(25,53)', 'Tetanus exc.Neo.', 'Tetanus neonatorum', 'Trichinosis', 'Tropical ulcer', 'Tuberculosis,total(32-34)', 'Pulmonary T.B.', 'T.B. other organs', 'T.B.meningitis', 'Yaw,infectious']
# 94

# %%
dfs = []
for i,name in enumerate(names):
    data= pd.read_excel(f"Data_Northern_Disease_excel/zone_summary_report({i+1}).xlsx",header = 30, skipfooter=2)
    df = data.iloc[:,:2]
    df.columns = ["Date",name]
#     print(df)
#     df[name] = df[name].str.replace("-","")
    dfs.append(df[name])
df1 = pd.concat(dfs,axis = 1)
# df1

# %%
from datetime import datetime
# start = "2010-01-01"
df1["Date"] = pd.DataFrame({"Date":pd.date_range(start = datetime(2010,1,1),end = datetime(2022,12,31),freq ="M").tolist()})

df1.set_index("Date",inplace = True)

# %%
import numpy as np
for column in df1.columns:
    df1[column] = df1[column].replace({"-":"None"})
df1
# Out:
#            Acute Flaccid Paralysis AEFI Amoebiasis other organ Anthrax  \
# Date
# 2010-01-31                       1   22                      2
# 2010-02-28                       2   16                      4
# 2010-03-31                       1    8
# 2010-04-30                       2    3                      1
# 2010-05-31                       1   10
# ...                            ...  ...                    ...     ...
# 2022-08-31
# 2022-09-30
# 2022-10-31
# 2022-11-30
# 2022-12-31
#
#            Brucellosis Capillariasis Cassava poisoning Chickenpox  \
# Date
# 2010-01-31                                                   1264
# 2010-02-28                         1                         1587
# 2010-03-31                         1                         2395
# 2010-04-30                                           1       1543
# 2010-05-31                                           1        582
# ...                ...           ...               ...        ...
# 2022-08-31
# 2022-09-30
# 2022-10-31
# 2022-11-30
# 2022-12-31
#
#            Chikungunya fever Cholera  ... Tetanus inc.Neo.(25,53)  \
# Date                                  ...
# 2010-01-31                 2          ...                       7
# 2010-02-28                            ...
# 2010-03-31                            ...
# 2010-04-30                            ...                       1
# 2010-05-31                            ...                       4
# ...                      ...     ...  ...                     ...
# 2022-08-31                            ...
# 2022-09-30                            ...
# 2022-10-31                            ...
# 2022-11-30                            ...
# 2022-12-31                            ...
#
#            Tetanus exc.Neo. Tetanus neonatorum Trichinosis Tropical ulcer  \
# Date
# 2010-01-31                6                  1                          5
# 2010-02-28                                                              1
# 2010-03-31                                                              6
# 2010-04-30                1                                             2
# 2010-05-31                3                  1                          6
# ...                     ...                ...         ...            ...
# 2022-08-31
# 2022-09-30
# 2022-10-31
# 2022-11-30
# 2022-12-31
#
#            Tuberculosis,total(32-34) Pulmonary T.B. T.B. other organs  \
# Date
# 2010-01-31                       525            277               235
# 2010-02-28                       379            244               124
# 2010-03-31                       427            257               156
# 2010-04-30                       456            297               157
# 2010-05-31                       534            374               144
# ...                              ...            ...               ...
# 2022-08-31
# 2022-09-30
# 2022-10-31
# 2022-11-30
# 2022-12-31
#
#            T.B.meningitis Yaw,infectious
# Date
# 2010-01-31             13
# 2010-02-28             11
# 2010-03-31             14
# 2010-04-30              2
# 2010-05-31             16
# ...                   ...            ...
# 2022-08-31
# 2022-09-30
# 2022-10-31
# 2022-11-30
# 2022-12-31
#
# [156 rows x 94 columns]

# %%
df1.to_excel("Data_Disease_Northen.xlsx",index = True , encoding = "utf-8-sig")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 156 entries, 2010-01-31 to 2022-12-31
# Data columns (total 94 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Acute Flaccid Paralysis        156 non-null    object
#  1   AEFI                           156 non-null    object
#  2   Amoebiasis other organ         156 non-null    object
#  3   Anthrax                        156 non-null    object
#  4   Brucellosis                    156 non-null    object
#  5   Capillariasis                  156 non-null    object
#  6   Cassava poisoning              156 non-null    object
#  7   Chickenpox                     156 non-null    object
#  8   Chikungunya fever              156 non-null    object
#  9   Cholera                        156 non-null    object
#  10  D.H.F,Total(26,27,66)          156 non-null    object
#  11  D.H.F.                         156 non-null    object
#  12  D.H.F.shock syndrome           156 non-null    object
#  13  Dengue fever                   156 non-null    object
#  14  Diarrhoea                      156 non-null    object
#  15  Diphtheria                     156 non-null    object
#  16  Drug poisoning                 156 non-null    object
#  17  Dysentery (04,05,06)           156 non-null    object
#  18  Dysentery,Amoebic              156 non-null    object
#  19  Dysentery,Bacillary            156 non-null    object
#  20  Uns.dysentery                  156 non-null    object
#  21  Encephalitis,total(28,29)      156 non-null    object
#  22  Encephalitis uns.              156 non-null    object
#  23  Japanese B encephalitis        156 non-null    object
#  24  Enteric fever(07,08,09)        156 non-null    object
#  25  Enteric fever                  156 non-null    object
#  26  Paratyphoid                    156 non-null    object
#  27  Typhoid                        156 non-null    object
#  28  Eosinophilic Meningitis        156 non-null    object
#  29  Filariasis                     156 non-null    object
#  30  Food Poisoning                 156 non-null    object
#  31  H.conjunctivitis               156 non-null    object
#  32  Hand,foot and mouth disease    156 non-null    object
#  33  Hepatitis,total (10-13,69-70)  156 non-null    object
#  34  Hepatitis A                    156 non-null    object
#  35  Hepatitis B                    156 non-null    object
#  36  Hepatitis C                    156 non-null    object
#  37  Hepatitis D                    156 non-null    object
#  38  Hepatitis E                    156 non-null    object
#  39  Hepatitis uns.                 156 non-null    object
#  40  Herpes zoster                  156 non-null    object
#  41  Influenza                      156 non-null    object
#  42  Kala azar                      156 non-null    object
#  43  Leprosy                        156 non-null    object
#  44  Leptospirosis                  156 non-null    object
#  45  Liver fluke                    156 non-null    object
#  46  Malaria                        156 non-null    object
#  47  Measles,total (21-22)          156 non-null    object
#  48  Measles                        156 non-null    object
#  49  Measles c Complication         156 non-null    object
#  50  Melioidosis                    156 non-null    object
#  51  Meningitis,uns.                156 non-null    object
#  52  Meningococcal Meningitis       156 non-null    object
#  53  Mumps                          156 non-null    object
#  54  Mushroom poisoning             156 non-null    object
#  55  Occupational diseases          156 non-null    object
#  56  Gas vapor poisoning            156 non-null    object
#  57  Lead poisoning                 156 non-null    object
#  58  Mn,Hg,As poisoning             156 non-null    object
#  59  Pesticide poisoning            156 non-null    object
#  60  Petroleum poisoning            156 non-null    object
#  61  Pertussis                      156 non-null    object
#  62  Physical Hazard                156 non-null    object
#  63  Pneumoconiosis                 156 non-null    object
#  64  Pneumonia                      156 non-null    object
#  65  Poliomyelitis                  156 non-null    object
#  66  Pyrexia                        156 non-null    object
#  67  Rabies                         156 non-null    object
#  68  Reye's syndrome                156 non-null    object
#  69  Rubella                        156 non-null    object
#  70  S.T.D.,total(37-41,79-81)      156 non-null    object
#  71  Chancroid                      156 non-null    object
#  72  Gonorrhoea                     156 non-null    object
#  73  L.G.V.                         156 non-null    object
#  74  N.S.U.                         156 non-null    object
#  75  Syphilis                       156 non-null    object
#  76  àÃÔÁ·ÕèÍÇÑÂÇÐà¾È               156 non-null    object
#  77  âÃ¤µÔ´µèÍ·Ò§à¾ÈÊÑÁ¾Ñ¹¸ìÍ×è¹ æ  156 non-null    object
#  78  ËÙ´ÍÇÑÂÇÐà¾ÈáÅÐ·ÇÒÃË¹Ñ¡        156 non-null    object
#  79  Scarlet fever                  156 non-null    object
#  80  Scrub Typhus                   156 non-null    object
#  81  Snake bite                     156 non-null    object
#  82  Streptococcus suis             156 non-null    object
#  83  Suicide                        156 non-null    object
#  84  Tetanus inc.Neo.(25,53)        156 non-null    object
#  85  Tetanus exc.Neo.               156 non-null    object
#  86  Tetanus neonatorum             156 non-null    object
#  87  Trichinosis                    156 non-null    object
#  88  Tropical ulcer                 156 non-null    object
#  89  Tuberculosis,total(32-34)      156 non-null    object
#  90  Pulmonary T.B.                 156 non-null    object
#  91  T.B. other organs              156 non-null    object
#  92  T.B.meningitis                 156 non-null    object
#  93  Yaw,infectious                 156 non-null    object
# dtypes: object(94)
# memory usage: 115.8+ KB
